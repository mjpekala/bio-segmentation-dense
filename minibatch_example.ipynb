# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os, sys, time
import numpy as np
import pylab as plt

from data_tools import *

np.random.seed(9999)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# load a test image
X = load_multilayer_tiff('/Users/pekalmj1/Data/ISBI-2012/train-volume.tif')
print('raw X shape: %s' % str(X.shape))

Y = load_multilayer_tiff('/Users/pekalmj1/Data/ISBI-2012/train-labels.tif')
print('raw Y shape: %s' % str(Y.shape))

plot0 = lambda X: plt.imshow(get_slice_0(X), cmap='bone')
# Out:
# raw X shape: (30, 1, 512, 512)
# raw Y shape: (30, 1, 512, 512)

# %%
# test some of the elementary operations
X_6 = apply_symmetry(X, 6)
X_rnd = apply_symmetry(X)

print(get_slice_0(X_6).shape)

plt.subplot(1,3,1)
plot0(X)
plt.subplot(1,3,2)
plot0(X_6)
plt.subplot(1,3,3)
plot0(X_rnd)
plt.show()


X_crop = random_crop(X, (500,500))
plt.subplot(1,2,1)
plot0(X)
plt.subplot(1,2,2)
plot0(X_crop)
# Out:
# (512, 512)

# %%
X_mb, Y_mb = random_minibatch(X, Y, 30, sz=(256,256))

plt.subplot(1,2,1)
plot0(X_mb)
plt.subplot(1,2,2)
plot0(Y_mb)
plt.show()
